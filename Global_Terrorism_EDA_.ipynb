# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragverse/EDA-on-Global-terrorism/blob/main/Global_Terrorism_EDA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Global Terrorism EDA
#
# **This project explores the Global Terrorism Database (1970–2017) to uncover patterns and insights about terrorist activities across the world.**

# %% [markdown]
# ![GIko7WcWsAAxyGY.jpg](data:image/jpeg;base64,...)

# %%
#load the necessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#display all columns
pd.set_option('display.max_columns',200)
#display all rows
pd.options.display.max_rows=None

# %%
#read the csv file...
df = pd.read_csv("globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')

# %%
#print the frist 5 row
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
#check the dataset shape
df.shape
# Out:
# (171056, 135)

# %%
#check the dtype of dataset
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171056 entries, 0 to 171055
# Data columns (total 135 columns):
#  #    Column              Dtype
# ---   ------              -----
#  0    eventid             int64
#  1    iyear               int64
#  2    imonth              int64
#  3    iday                int64
#  4    approxdate          object
#  5    extended            int64
#  6    resolution          object
#  7    country             int64
#  8    country_txt         object
#  9    region              int64
#  10   region_txt          object
#  11   provstate           object
#  12   city                object
#  13   latitude            float64
#  14   longitude           float64
#  15   specificity         float64
#  16   vicinity            int64
#  17   location            object
#  18   summary             object
#  19   crit1               int64
#  20   crit2               int64
#  21   crit3               int64
#  22   doubtterr           float64
# ...

# %%
#check the describe function
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.710560e+05  171056.000000  171056.000000  171056.000000
# mean   2.001812e+11    2001.746142       6.467630      15.457002
# std    1.315779e+09      13.157652       3.396398       8.821531
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.990060e+11    1990.000000       4.000000       8.000000
# 50%    2.008012e+11    2008.000000       6.000000      15.000000
# 75%    2.014030e+11    2014.000000       9.000000      23.000000
# max    2.017011e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  171056.000000  171056.000000  171056.000000  166546.000000
# mean        0.043869     132.471764       7.096536      23.402498
# std         0.204803     112.837542       2.949416      18.824729
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#check the null values
df.isnull().sum()
# Out:
# eventid                    0
# iyear                      0
# imonth                     0
# iday                       0
# approxdate            163481
# extended                   0
# resolution            168836
# country                    0
# country_txt                0
# region                     0
# region_txt                 0
# provstate                420
# city                     435
# latitude                4510
# longitude               4511
# specificity                6
# vicinity                   0
# location              122753
# summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           144255
# alternative_txt       144255
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
# attacktype2           165394
# attacktype2_txt       165394
# ...

# %%
#check the duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#select the feature
col= ["iyear","imonth",'iday','country_txt','city','region_txt','latitude','longitude','attacktype1_txt','success','suicide','target1','targtype1_txt','gname','motive','weaptype1_txt',"nkill",'nwound','summary']

# %%
new_df = df[col]
new_df.head()  #print the frist 5 rows
# Out:
#    iyear  imonth  iday         country_txt           city  \
# 0   1970       7     2  Dominican Republic  Santo Domingo
# 1   1970       0     0              Mexico    Mexico city
# 2   1970       1     0         Philippines        Unknown
# 3   1970       1     0              Greece         Athens
# 4   1970       1     0               Japan        Fukouka
#
#                     region_txt   latitude   longitude  \
# 0  Central America & Caribbean  18.456792  -69.951164
# 1                North America  19.371887  -99.086624
# 2               Southeast Asia  15.478598  120.599741
# 3               Western Europe  37.997490   23.762728
# 4                    East Asia  33.580412  130.396361
#
#                   attacktype1_txt  success  suicide                  target1  \
# 0                   Assassination        1        0             Julio Guzman
# 1     Hostage Taking (Kidnapping)        1        0  Nadine Chaval, daughter
# ...

# %%
#check the new dataframe shape
new_df.shape
# Out:
# (171056, 19)

# %%
#rename the columns
new_df = new_df.rename(columns={'iyear':"year",'imonth':'month','iday':'day','country_txt':'country_name','region_txt':'region_name','attacktype1_txt':'attack_type','target1':'target','targtype1_txt':'traget_type','gname':'group_name','weaptype1_txt':'weapan_type','nkill':'number_of_kills','nwound':'wouned'})

# %%
new_df.head()
# Out:
#    year  month  day        country_name           city  \
# 0  1970      7    2  Dominican Republic  Santo Domingo
# 1  1970      0    0              Mexico    Mexico city
# 2  1970      1    0         Philippines        Unknown
# 3  1970      1    0              Greece         Athens
# 4  1970      1    0               Japan        Fukouka
#
#                    region_name   latitude   longitude  \
# 0  Central America & Caribbean  18.456792  -69.951164
# 1                North America  19.371887  -99.086624
# 2               Southeast Asia  15.478598  120.599741
# 3               Western Europe  37.997490   23.762728
# 4                    East Asia  33.580412  130.396361
#
#                       attack_type  success  suicide                   target  \
# 0                   Assassination        1        0             Julio Guzman
# 1     Hostage Taking (Kidnapping)        1        0  Nadine Chaval, daughter
# ...

# %%
#check the null value in the new dataframe
new_df.isnull().sum()
# Out:
# year                    0
# month                   0
# day                     0
# country_name            0
# city                  435
# region_name             0
# latitude             4510
# longitude            4511
# attack_type             0
# success                 0
# suicide                 0
# target                638
# traget_type             0
# group_name              0
# motive             122364
# weapan_type             0
# number_of_kills      9711
# wouned              15372
# summary             66129
# dtype: int64

# %%
#check the duplicat values
new_df.duplicated().sum()
# Out:
# np.int64(9186)

# %%
#drop the duplicate values
new_df.drop_duplicates(keep='first', inplace=True)

# %%
new_df.isnull().sum()
# Out:
# year                    0
# month                   0
# day                     0
# country_name            0
# city                  435
# region_name             0
# latitude             3971
# longitude            3972
# attack_type             0
# success                 0
# suicide                 0
# target                547
# traget_type             0
# group_name              0
# motive             113792
# weapan_type             0
# number_of_kills      8859
# wouned              14366
# summary             59107
# dtype: int64

# %%
#add columns casualities
new_df["casualities"] = new_df.number_of_kills+new_df.wouned

# %% [markdown]
# ## Number Of Terrorist Activities Each Year

# %%
#year wise terrorist attactes
plt.subplots(figsize=(25,6))
sns.countplot(x='year', data=new_df )
plt.xticks(rotation=90)
plt.title("Number of acctive terrorist at each years")
# Out:
# Text(0.5, 1.0, 'Number of acctive terrorist at each years')

# %% [markdown]
# ## Terrorist Activities by Region in each Year

# %%
#terrorist active region
pd.crosstab(new_df.year, new_df.region_name).plot(kind="area",figsize=(20,6))
plt.title("Terrorist Activities by Region in each Year")
plt.ylabel("Number of attacts")
plt.xlabel("Years")
# Out:
# Text(0.5, 0, 'Years')

# %%
r_type = new_df.region_name.value_counts().to_frame().reset_index()
r_type.columns = ['region_name','count']

# %%
sns.barplot(y='region_name', x='count',data=r_type,orient='h',palette='flare')
plt.title("Number of Total Attacks in Each Region")
plt.ylabel('Region')
plt.xlabel('Number of attacks')
# Out:
# Text(0.5, 0, 'Number of attacks')

# %% [markdown]
# we can notice from the previous figure that (Middle East & North Africa) and (south Asia) have huge increase in last 10 years.

# %% [markdown]
# ## Number of total attacks of each country

# %%
top_10_country = new_df.country_name.value_counts()[:10].to_frame().reset_index()
top_10_country.columns = ["country_name",'count']
top_10_country
# Out:
#      country_name  count
# 0            Iraq  21218
# 1        Pakistan  13119
# 2     Afghanistan  11166
# 3           India  10640
# 4        Colombia   7397
# 5     Philippines   6092
# 6            Peru   5044
# 7  United Kingdom   4880
# 8     El Salvador   4302
# 9          Turkey   3918

# %%
plt.figure(figsize=(15,5))
sns.barplot(data = top_10_country,x ='country_name',y='count',palette = 'flare')
plt.title("Top 10 Country of Attacks")
plt.xlabel("Country")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# **we can notice that the first three affected countries by terrorism are from Middle East**

# %% [markdown]
# ## Target Methods by Terrorists

# %%
t_type = new_df.traget_type.value_counts()[:10].to_frame().reset_index()
t_type.columns = ["target_type",'count']

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='target_type',y='count',data=t_type,palette = 'coolwarm')
plt.title("Target method by terrorists")
plt.xlabel("Target type")
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ## Weapons  used by Terrorist

# %%
w_type = new_df.weapan_type.value_counts().to_frame().reset_index()
w_type.columns = ['weapan_type','count']

# %%
plt.figure(figsize=(25,5))
sns.barplot(x='weapan_type',y='count',data=w_type,palette='flare')
plt.title('Weapan used by terrorist')
plt.xlabel("weapan_type")
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
g_type = new_df.group_name.value_counts()[:5].to_frame().reset_index()
g_type.columns = ['group_name','count']

# %%
plt.figure(figsize=(15,4))
sns.barplot(x='group_name', y='count', data=g_type, palette='flare')
plt.title('Group Name')
plt.xlabel("group_name")
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# **we can notice most dangerous and active group is taliban**

# %% [markdown]
# ## Number of Total Casualities in Each Country

# %%
top10_c = new_df.groupby('country_name').casualities.sum().to_frame().reset_index().sort_values('casualities',ascending = False)[:10]
top10_c
# Out:
#       country_name  casualities
# 84            Iraq     192093.0
# 0      Afghanistan      68612.0
# 134       Pakistan      60827.0
# 80           India      45285.0
# 167      Sri Lanka      29422.0
# 189  United States      23451.0
# 35        Colombia      22950.0
# 140    Philippines      21056.0
# 130        Nigeria      19268.0
# 2          Algeria      19086.0

# %%
sns.barplot(x='casualities',y='country_name',data=top10_c, orient='h',palette="coolwarm")
plt.title("Number of Total Casualities in Each Country")
plt.xlabel("Casualities")
plt.ylabel("country_name")
# Out:
# Text(0, 0.5, 'country_name')

# %% [markdown]
# **Iraq has has the highest number of casulities people.**

# %% [markdown]
# **Conclusion**
#
# Through this exploratory data analysis of global terrorism incidents from 1970 to 2017, we have identified crucial patterns and trends that help in understanding the scope and evolution of terrorism worldwide. The data reveals that terrorist activities have significantly increased in the last two decades, especially in regions like the Middle East & North Africa and South Asia.
#
# Countries such as Iraq, Pakistan, Afghanistan, and India have been consistently among the most targeted. The most commonly used attack types are bombings/explosions and armed assaults, with private citizens and government entities being the primary targets. Groups like Taliban and ISIS have carried out the majority of these attacks in recent years.
#
# By analyzing casualties, attack patterns, and regional data, this project provides actionable insights that can aid policymakers, security analysts, and researchers in understanding terrorism dynamics and formulating better counter-terrorism strategies. Continued data-driven analysis can contribute toward making the world a safer place.
